# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from jcopml.pipeline import num_pipe, cat_pipe
from jcopml.utils import save_model, load_model
from jcopml.plot import plot_missing_value
from jcopml.feature_importance import mean_score_decrease

# %%
df = pd.read_csv("data/cerealKeren.csv")
df.head()
# Out:
#    Unnamed: 0                       name mfr type  calories  protein  fat  \
# 0           0                  100% Bran   N    C        70        4    1
# 1           1          100% Natural Bran   Q    C       120        3    5
# 2           2                   All-Bran   K    C        70        4    1
# 3           3  All-Bran with Extra Fiber   K    C        50        4    0
# 4           4             Almond Delight   R    C       110        2    2
#
#    sodium  fiber carbo sugars potass vitamins  shelf  weight  cups     rating
# 0     130   10.0   5.0    6.0  280.0   FDA_25      3     1.0  0.33  68.402973
# 1      15    2.0   8.0    8.0  135.0    FDA_0      3     1.0  1.00  33.983679
# 2     260    9.0   7.0    5.0  320.0   FDA_25      3     1.0  0.33  59.425505
# 3     140   14.0   8.0    0.0  330.0   FDA_25      3     1.0  0.50  93.704912
# 4     200    1.0  14.0    8.0  ready   FDA_25      3     1.0  0.75  34.384843

# %%
df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#   carbo sugars potass vitamins  shelf  weight  cups     rating
# 0   5.0    6.0  280.0   FDA_25      3     1.0  0.33  68.402973
# 1   8.0    8.0  135.0    FDA_0      3     1.0  1.00  33.983679
# 2   7.0    5.0  320.0   FDA_25      3     1.0  0.33  59.425505
# 3   8.0    0.0  330.0   FDA_25      3     1.0  0.50  93.704912
# 4  14.0    8.0  ready   FDA_25      3     1.0  0.75  34.384843

# %%
df[(df["rating"] > 30) & (df["mfr"].isin(["N", "K"]))].head()
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 6                 Apple Jacks   K    C       110        2    0     125    1.0
# 16                Corn Flakes   K    C       100        2    0     290    1.0
#
#    carbo sugars potass vitamins  shelf  weight  cups     rating
# 0    5.0    6.0  280.0   FDA_25      3     1.0  0.33  68.402973
# 2    7.0    5.0  320.0   FDA_25      3     1.0  0.33  59.425505
# 3    8.0    0.0  330.0   FDA_25      3     1.0  0.50  93.704912
# 6   11.0   14.0   30.0   FDA_25      2     1.0  1.00  33.174094
# 16  21.0    2.0   35.0   FDA_25      1     1.0  1.00  45.863324

# %%
df[(df["rating"] > 30) & (df["mfr"].isin(["N", "K"]))].mean()
# Out:
# C:\Users\TOKOFE~1\AppData\Local\Temp/ipykernel_15204/336321646.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[(df["rating"] > 30) & (df["mfr"].isin(["N", "K"]))].mean()
# calories    103.571429
# protein       2.714286
# fat           0.500000
# sodium      144.821429
# fiber         3.107143
# shelf         2.214286
# weight        1.057857
# cups          0.796786
# rating       49.670420
# dtype: float64

# %%
keren = df[(df["rating"] > 30) & (df["mfr"].isin(["N", "K"]))].copy()
keren.sort_values(by="rating", ascending=False, inplace=True)
keren.head()
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
#
#    carbo sugars potass vitamins  shelf  weight  cups     rating
# 3    8.0    0.0  330.0   FDA_25      3    1.00  0.50  93.704912
# 64  19.0    0.0  140.0    FDA_0      1    1.00  0.67  74.472949
# 65  20.0    0.0  120.0    FDA_0      1    1.00  0.67  72.801787
# 0    5.0    6.0  280.0   FDA_25      3    1.00  0.33  68.402973
# 63  16.0    0.0   95.0    FDA_0      1    0.83  1.00  68.235885

# %%
keren.groupby("mfr").mean()
# Out:
#        calories   protein       fat      sodium     fiber     shelf    weight  \
# mfr
# K    108.181818  2.681818  0.590909  174.090909  2.863636  2.363636  1.081364
# N     86.666667  2.833333  0.166667   37.500000  4.000000  1.666667  0.971667
#
#          cups     rating
# mfr
# K    0.801818  44.680016
# N    0.778333  67.968567

# %%
df.groupby(["mfr", "shelf"]).rating.agg(["mean", "std", "count"])
# Out:
#                 mean        std  count
# mfr shelf
# A   2      54.850917        NaN      1
# G   1      39.872079   9.533802      6
#     2      26.069929   6.396781      7
#     3      37.440751   5.390828      9
# K   1      42.747695   9.133588      4
#     2      37.131878   9.857668      7
#     3      48.497559  17.018441     12
# N   1      71.836874   3.228550      3
#     2      61.948905   3.655617      2
#     3      68.402973        NaN      1
# P   1      31.997429   4.603286      2
#     2      28.025765        NaN      1
#     3      47.221846   6.756369      6
# Q   1      50.828392        NaN      1
#     2      28.414072  14.772502      3
#     3      51.814327  13.271956      4
# R   1      45.587913   4.478015      4
#     3      37.498082   4.753519      4

# %%
df.pivot_table(index="mfr", columns="shelf", values="rating", aggfunc=["mean", "std", "count"])
# Out:
#             mean                             std                       count  \
# shelf          1          2          3         1          2          3     1
# mfr
# A            NaN  54.850917        NaN       NaN        NaN        NaN   NaN
# G      39.872079  26.069929  37.440751  9.533802   6.396781   5.390828   6.0
# K      42.747695  37.131878  48.497559  9.133588   9.857668  17.018441   4.0
# N      71.836874  61.948905  68.402973  3.228550   3.655617        NaN   3.0
# P      31.997429  28.025765  47.221846  4.603286        NaN   6.756369   2.0
# Q      50.828392  28.414072  51.814327       NaN  14.772502  13.271956   1.0
# R      45.587913        NaN  37.498082  4.478015        NaN   4.753519   4.0
#
#
# shelf    2     3
# mfr
# A      1.0   NaN
# G      7.0   9.0
# K      7.0  12.0
# N      2.0   1.0
# P      1.0   6.0
# Q      3.0   4.0
# R      NaN   4.0

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#   carbo sugars potass vitamins  shelf  weight  cups     rating
# 0   5.0    6.0  280.0   FDA_25      3     1.0  0.33  68.402973
# 1   8.0    8.0  135.0    FDA_0      3     1.0  1.00  33.983679
# 2   7.0    5.0  320.0   FDA_25      3     1.0  0.33  59.425505
# 3   8.0    0.0  330.0   FDA_25      3     1.0  0.50  93.704912
# 4  14.0    8.0  ready   FDA_25      3     1.0  0.75  34.384843

# %%
df.shape
# Out:
# (77, 16)

# %%
len(df)
# Out:
# 77

# %%
df["kolomKeren"] = np.random.rand(len(df))

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#   carbo sugars potass vitamins  shelf  weight  cups     rating  kolomKeren
# 0   5.0    6.0  280.0   FDA_25      3     1.0  0.33  68.402973    0.383753
# 1   8.0    8.0  135.0    FDA_0      3     1.0  1.00  33.983679    0.992150
# 2   7.0    5.0  320.0   FDA_25      3     1.0  0.33  59.425505    0.280479
# 3   8.0    0.0  330.0   FDA_25      3     1.0  0.50  93.704912    0.893086
# 4  14.0    8.0  ready   FDA_25      3     1.0  0.75  34.384843    0.620341

# %%
df.drop(["kolomKeren"], axis=1, inplace=True)

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#   carbo sugars potass vitamins  shelf  weight  cups     rating
# 0   5.0    6.0  280.0   FDA_25      3     1.0  0.33  68.402973
# 1   8.0    8.0  135.0    FDA_0      3     1.0  1.00  33.983679
# 2   7.0    5.0  320.0   FDA_25      3     1.0  0.33  59.425505
# 3   8.0    0.0  330.0   FDA_25      3     1.0  0.50  93.704912
# 4  14.0    8.0  ready   FDA_25      3     1.0  0.75  34.384843

# %%
df["shelf_name"] = df.shelf.map({1: "bawah", 2: "tengah", 3: "atas"})

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#   carbo sugars potass vitamins  shelf  weight  cups     rating shelf_name
# 0   5.0    6.0  280.0   FDA_25      3     1.0  0.33  68.402973       atas
# 1   8.0    8.0  135.0    FDA_0      3     1.0  1.00  33.983679       atas
# 2   7.0    5.0  320.0   FDA_25      3     1.0  0.33  59.425505       atas
# 3   8.0    0.0  330.0   FDA_25      3     1.0  0.50  93.704912       atas
# 4  14.0    8.0  ready   FDA_25      3     1.0  0.75  34.384843       atas

# %%
def convertGtoMg(x):
  return x*1000

def convertToLower(x):
  return x.lower()

# %%
df["fatMg"] = df["fat"].apply(convertGtoMg)

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#   carbo sugars potass vitamins  shelf  weight  cups     rating shelf_name  \
# 0   5.0    6.0  280.0   FDA_25      3     1.0  0.33  68.402973       atas
# 1   8.0    8.0  135.0    FDA_0      3     1.0  1.00  33.983679       atas
# 2   7.0    5.0  320.0   FDA_25      3     1.0  0.33  59.425505       atas
# 3   8.0    0.0  330.0   FDA_25      3     1.0  0.50  93.704912       atas
# 4  14.0    8.0  ready   FDA_25      3     1.0  0.75  34.384843       atas
#
#    fatMg
# 0   1000
# 1   5000
# 2   1000
# 3      0
# 4   2000

# %%
df["mfrToLower"] = df["mfr"].apply(convertToLower)

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#   carbo sugars potass vitamins  shelf  weight  cups     rating shelf_name  \
# 0   5.0    6.0  280.0   FDA_25      3     1.0  0.33  68.402973       atas
# 1   8.0    8.0  135.0    FDA_0      3     1.0  1.00  33.983679       atas
# 2   7.0    5.0  320.0   FDA_25      3     1.0  0.33  59.425505       atas
# 3   8.0    0.0  330.0   FDA_25      3     1.0  0.50  93.704912       atas
# 4  14.0    8.0  ready   FDA_25      3     1.0  0.75  34.384843       atas
#
#    fatMg mfrToLower
# 0   1000          n
# 1   5000          q
# 2   1000          k
# 3      0          k
# 4   2000          r

# %%
df["UseLambdafatMg"] = df["fat"].apply(lambda x: x*1000)

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#   carbo sugars potass vitamins  shelf  weight  cups     rating shelf_name  \
# 0   5.0    6.0  280.0   FDA_25      3     1.0  0.33  68.402973       atas
# 1   8.0    8.0  135.0    FDA_0      3     1.0  1.00  33.983679       atas
# 2   7.0    5.0  320.0   FDA_25      3     1.0  0.33  59.425505       atas
# 3   8.0    0.0  330.0   FDA_25      3     1.0  0.50  93.704912       atas
# 4  14.0    8.0  ready   FDA_25      3     1.0  0.75  34.384843       atas
#
#    fatMg mfrToLower  UseLambdafatMg
# 0   1000          n            1000
# 1   5000          q            5000
# 2   1000          k            1000
# 3      0          k               0
# 4   2000          r            2000

# %%
df["scaledRating"] = df["rating"].transform(lambda x: (x-x.min())/(x.max()-x.min()))

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#   carbo sugars  ... vitamins shelf  weight  cups     rating  shelf_name fatMg  \
# 0   5.0    6.0  ...   FDA_25     3     1.0  0.33  68.402973        atas  1000
# 1   8.0    8.0  ...    FDA_0     3     1.0  1.00  33.983679        atas  5000
# 2   7.0    5.0  ...   FDA_25     3     1.0  0.33  59.425505        atas  1000
# 3   8.0    0.0  ...   FDA_25     3     1.0  0.50  93.704912        atas     0
# 4  14.0    8.0  ...   FDA_25     3     1.0  0.75  34.384843        atas  2000
#
#    mfrToLower UseLambdafatMg  scaledRating
# 0           n           1000      0.665593
# 1           q           5000      0.210685
# 2           k           1000      0.546941
# 3           k              0      1.000000
# 4           r           2000      0.215987
#
# [5 rows x 21 columns]

# %%
df["scaledRating"] = df["rating"].apply(lambda x: (x-x.min())/(x.max()-x.min()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\TOKOFE~1\AppData\Local\Temp/ipykernel_15204/1592467043.py in <module>
# ----> 1 df["scaledRating"] = df["rating"].apply(lambda x: (x-x.min())/(x.max()-x.min()))
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# C:\Users\TOKOFE~1\AppData\Local\Temp/ipykernel_15204/1592467043.py in <lambda>(x)
# ----> 1 df["scaledRating"] = df["rating"].apply(lambda x: (x-x.min())/(x.max()-x.min()))
#
# AttributeError: 'float' object has no attribute 'min'
